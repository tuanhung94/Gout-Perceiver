# %%
import torch

import torch.nn as nn

import torch.nn.functional as F

import torchvision

import torchvision.transforms as transforms

from torch.utils.data import DataLoader, TensorDataset

import matplotlib.pyplot as plt

import pandas as pd

import numpy as np

import math

import time

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# %run Data_Processing.ipynb
# Out:
# Mapping files: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 65.23it/s]
# Mapping files: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 68.22it/s]
# The proportion of 0's in the genomic dataset is 33.34 %
# The proportion of 1's in the genomic dataset is 33.34 %
# The proportion of 2's in the genomic dataset is 33.32 %
# The proportion of NaN's in the genomic dataset is 0.00 %
# The proportion of having gout is 0.41
# Mapping files: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 69.79it/s]
# Mapping files: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 73.19it/s]
# C:\Users\tuanh\AppData\Local\Temp\ipykernel_148\2141829978.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['encoded_sex'] = np.select([df['sex'] == "Male" , df['sex'] == "Female"], [1, 2])
# C:\Users\tuanh\AppData\Local\Temp\ipykernel_148\2141829978.py:15: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:233.)
#   phenos_tensor = torch.Tensor(list(df.values))
# C:\Users\tuanh\AppData\Local\Temp\ipykernel_148\2141829978.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['encoded_sex'] = np.select([df['sex'] == "Male" , df['sex'] == "Female"], [1, 2])
# C:\Users\tuanh\AppData\Local\Temp\ipykernel_148\2141829978.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['encoded_sex'] = np.select([df['sex'] == "Male" , df['sex'] == "Female"], [1, 2])

# %% [markdown]
# ## Fully Connected FeedForward Neural Network Layer

# %%
class FFNLayer(nn.Module):
    
    def __init__(self, hidden_size_1, hidden_size_2, output_size):
        
        super().__init__()
        
        self.layer1 = nn.LazyLinear(hidden_size_1)
        
        self.layer2 = nn.LazyLinear(hidden_size_2)
        
        self.layer3 = nn.LazyLinear(output_size)
        
    def forward(self, inputs):
        
        first_outputs = F.gelu(self.layer1(inputs))
        
        second_outputs = F.gelu(self.layer2(first_outputs))
        
        final_outputs = self.layer3(second_outputs)
        
        return final_outputs

# %%
class NeuralNetwork(nn.Module):
    
    def __init__(self, hidden_size_1, hidden_size_2):
        
        super().__init__()
        
        self.softmax = nn.Softmax(dim=1)
        
        self.ffn = FFNLayer(hidden_size_1, hidden_size_2, 2)
        
    def forward(self, inputs):
            
        inputs = inputs.reshape(inputs.shape[0], -1)
            
        # outputs = F.relu(inputs)
        
        outputs_ffn = F.gelu(self.ffn(inputs))
        
        outputs_final = self.softmax(outputs_ffn)
              
        return outputs_final

# %% [markdown]
# ## One Hot Encoding of the tokenised SNV data

# %%
class One_Hot_Encoding(nn.Module):
    
    def __init__(self, num_classes: int):
        
        super().__init__()
        
        self.num_classes = num_classes
        
    def forward(self, input_ts):
        
        return F.one_hot(input_ts.long(), num_classes = self.num_classes)

# %% [markdown]
# ## Positional Encoding

# %%
class Positional_Encoding(nn.Module):
    
    def __init__(self, pos_dim, dropout):
        
        super().__init__()
        
        self.dropout = nn.Dropout(dropout)
        
        self.pos_dim = pos_dim
        
    def forward(self, input_ts):
        
        num_len = input_ts.shape[1]
        
        #num_dim = input_ts.shape[2]
        
        P = torch.zeros(1, num_len, self.pos_dim)
        
        X = (torch.arange(num_len, dtype=torch.float32).reshape(-1, 1) / 
        torch.pow(10000, torch.arange(0, self.pos_dim, 2, dtype = torch.float32) / self.pos_dim))
        
        P[:, :, 0::2] = torch.sin(X)
        
        if (self.pos_dim % 2) == 1:
            
            P[:, :, 1::2] = torch.cos(X[:, :-1])
            
        else:    
            
            P[:, :, 1::2] = torch.cos(X)
        
        P = torch.repeat_interleave(P, repeats = input_ts.shape[0], dim = 0)
        
        return self.dropout(P[:, :input_ts.shape[1], :].to(input_ts.device))

# %% [markdown]
# ## Processing the raw datasets

# %%
class prepare_dataset(nn.Module):
    
    def __init__(self, num_classes: int, phenos_or_not: bool, pos_dim: int, dropout):
        
        super().__init__()
        
        self.one_hot_encoding = One_Hot_Encoding(num_classes)
        
        self.positional_encoding = Positional_Encoding(pos_dim, dropout)
        
        self.num_classes = num_classes
        
        self.phenos_or_not = phenos_or_not
        
    def forward(self, snv_ts, phenos_ts):
        
        # Process tokenised SNV data
        
        encoded_snv_ts = self.one_hot_encoding(snv_ts)
        
        pos_encoded_snv_ts = self.positional_encoding(encoded_snv_ts)
        
        if self.phenos_or_not:
            
            # Process phenotypes data
            
            phenos_ts = phenos_ts.unsqueeze(0)
            
            phenos_ts = torch.repeat_interleave(phenos_ts, repeats = snv_ts.shape[1], dim = 1)
            
            phenos_ts = phenos_ts.reshape(-1, snv_ts.shape[1], phenos_ts.shape[2])
            
            # Join encoded SNV and phenotypes datasets
            
            complete_ts = torch.cat((encoded_snv_ts, pos_encoded_snv_ts, phenos_ts), dim = 2)
            
        else:
            
            #complete_ts = torch.cat((encoded_snv_ts, pos_encoded_snv_ts), dim = 2)
            
            #complete_ts = snv_ts.to(torch.float32)
            
            complete_ts = encoded_snv_ts.to(torch.float32)
            
        return complete_ts

# %%
pros = prepare_dataset(num_classes = 3, phenos_or_not = False, pos_dim = 3, dropout = 0.0)

# %%
train_df = pros(tr_snv, tr_phenos)

# %%
train_df.shape
# Out:
# torch.Size([6999, 2000, 3])

# %%
test_df = pros(te_snv, te_phenos)

# %%
test_df.shape
# Out:
# torch.Size([2500, 2000, 3])

# %%
tr_gout.shape
# Out:
# torch.Size([6999])

# %%
te_gout.shape
# Out:
# torch.Size([2500])

# %%
# Merge data and labels

train_ts = TensorDataset(train_df, tr_gout)

test_ts = TensorDataset(test_df, te_gout)

# %%
# Loading training and testing datasets

train_dataloader = DataLoader(train_ts, batch_size = 10, shuffle = True)

#label_tr_dataloader = torch.utils.data.DataLoader(tr_gout, batch_size = 10, shuffle = False)

test_dataloader = DataLoader(test_ts, batch_size = 5, shuffle = False)

#label_te_dataloader = torch.utils.data.DataLoader(te_gout, batch_size = 4, shuffle = False)

# %%
epoch_list = np.around(np.arange(0 + 1/3, 25 + 1/3, 1/3), 1)

loss_values_4 = np.repeat(0, 75)

loss_values_8 = np.repeat(0, 75)

loss_values_16 = np.repeat(0, 75)

loss_values_32 = np.repeat(0, 75)

loss_values_64 = np.repeat(0, 75)

loss_values_128 = np.repeat(0, 75)

loss_values_256 = np.repeat(0, 75)

# %%
epoch_df = pd.DataFrame({'epoch_value': epoch_list, 'loss_value_4': loss_values_4,
                         'loss_value_8': loss_values_8, 'loss_value_16': loss_values_16,
                        'loss_values_32': loss_values_32, 'loss_value_64': loss_values_64,
                        'loss_values_128': loss_values_128, 'loss_values_256': loss_values_256})

# %%
overall_accuracy = np.repeat(0, 7)

accuracy_not_gout = np.repeat(0, 7)

accuracy_gout = np.repeat(0, 7)

precision_not_gout = np.repeat(0, 7)

precision_gout = np.repeat(0, 7)

training_time = np.repeat(0, 7)

# %%
result_df = pd.DataFrame({'overall_accuracy': overall_accuracy, 'accuracy_not_gout': accuracy_not_gout,
                         'accuracy_gout': accuracy_gout, 'precision_not_gout': precision_not_gout,
                        'precision_gout': precision_gout, 'training_time': training_time})

# %%
result_df.index = ['hidden_size_4', 'hidden_size_8', 'hidden_size_16', 'hidden_size_32', 
                   'hidden_size_64', 'hidden_size_128', 'hidden_size_256']

# %% [markdown]
# ## Hidden Layer Size = 4

# %%
model = NeuralNetwork(hidden_size_1 = 4, hidden_size_2 = 4)
# Out:
# C:\Users\tuanh\anaconda3\envs\pytorch\lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %%
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr = 1e-5, amsgrad = True)

epochs = 25

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
model = model.to(device)

# %%
n_total_steps = len(train_dataloader)

# %%
start_time = time.time()

# %%
loss_count = 0

model.train()

for epoch in range(epochs):
    
    for i, (seqs, labels) in enumerate(train_dataloader):
        
        #labels = torch.unsqueeze(labels, 1)
        
        #seqs = torch.unsqueeze(seqs, 1)
        
        seqs = seqs.to(device)
        
        labels = labels.to(device)
        
        outputs = model(seqs)
        
        loss = criterion(outputs, labels)
        
        optimizer.zero_grad()
        
        loss.backward()
        
        optimizer.step()
        
        if (i+1) % 200 == 0:
            
            print (f'Epoch [{epoch+1}/{epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.3f}')
            
            epoch_df.iloc[loss_count, 1] = round(loss.item(), 2)
            
            loss_count += 1
# Out:
# Epoch [1/25], Step [200/700], Loss: 0.702
# Epoch [1/25], Step [400/700], Loss: 0.640
# Epoch [1/25], Step [600/700], Loss: 0.676
# Epoch [2/25], Step [200/700], Loss: 0.705
# Epoch [2/25], Step [400/700], Loss: 0.602
# Epoch [2/25], Step [600/700], Loss: 0.666
# Epoch [3/25], Step [200/700], Loss: 0.778
# Epoch [3/25], Step [400/700], Loss: 0.649
# Epoch [3/25], Step [600/700], Loss: 0.681
# Epoch [4/25], Step [200/700], Loss: 0.704
# Epoch [4/25], Step [400/700], Loss: 0.699
# Epoch [4/25], Step [600/700], Loss: 0.672
# Epoch [5/25], Step [200/700], Loss: 0.602
# Epoch [5/25], Step [400/700], Loss: 0.694
# Epoch [5/25], Step [600/700], Loss: 0.594
# Epoch [6/25], Step [200/700], Loss: 0.729
# Epoch [6/25], Step [400/700], Loss: 0.636
# Epoch [6/25], Step [600/700], Loss: 0.697
# Epoch [7/25], Step [200/700], Loss: 0.626
# Epoch [7/25], Step [400/700], Loss: 0.622
# Epoch [7/25], Step [600/700], Loss: 0.695
# Epoch [8/25], Step [200/700], Loss: 0.607
# Epoch [8/25], Step [400/700], Loss: 0.725
# Epoch [8/25], Step [600/700], Loss: 0.700
# Epoch [9/25], Step [200/700], Loss: 0.682
# Epoch [9/25], Step [400/700], Loss: 0.682
# Epoch [9/25], Step [600/700], Loss: 0.665
# Epoch [10/25], Step [200/700], Loss: 0.721
# Epoch [10/25], Step [400/700], Loss: 0.663
# Epoch [10/25], Step [600/700], Loss: 0.672
# Epoch [11/25], Step [200/700], Loss: 0.628
# Epoch [11/25], Step [400/700], Loss: 0.733
# Epoch [11/25], Step [600/700], Loss: 0.590
# Epoch [12/25], Step [200/700], Loss: 0.761
# Epoch [12/25], Step [400/700], Loss: 0.720
# Epoch [12/25], Step [600/700], Loss: 0.578
# Epoch [13/25], Step [200/700], Loss: 0.751
# Epoch [13/25], Step [400/700], Loss: 0.745
# Epoch [13/25], Step [600/700], Loss: 0.702
# Epoch [14/25], Step [200/700], Loss: 0.552
# Epoch [14/25], Step [400/700], Loss: 0.675
# Epoch [14/25], Step [600/700], Loss: 0.670
# Epoch [15/25], Step [200/700], Loss: 0.685
# Epoch [15/25], Step [400/700], Loss: 0.615
# Epoch [15/25], Step [600/700], Loss: 0.650
# Epoch [16/25], Step [200/700], Loss: 0.688
# Epoch [16/25], Step [400/700], Loss: 0.569
# Epoch [16/25], Step [600/700], Loss: 0.621
# Epoch [17/25], Step [200/700], Loss: 0.615
# Epoch [17/25], Step [400/700], Loss: 0.655
# Epoch [17/25], Step [600/700], Loss: 0.710
# Epoch [18/25], Step [200/700], Loss: 0.625
# Epoch [18/25], Step [400/700], Loss: 0.596
# Epoch [18/25], Step [600/700], Loss: 0.647
# Epoch [19/25], Step [200/700], Loss: 0.749
# Epoch [19/25], Step [400/700], Loss: 0.681
# Epoch [19/25], Step [600/700], Loss: 0.646
# Epoch [20/25], Step [200/700], Loss: 0.600
# Epoch [20/25], Step [400/700], Loss: 0.594
# Epoch [20/25], Step [600/700], Loss: 0.800
# Epoch [21/25], Step [200/700], Loss: 0.644
# Epoch [21/25], Step [400/700], Loss: 0.665
# Epoch [21/25], Step [600/700], Loss: 0.650
# Epoch [22/25], Step [200/700], Loss: 0.665
# Epoch [22/25], Step [400/700], Loss: 0.597
# Epoch [22/25], Step [600/700], Loss: 0.592
# Epoch [23/25], Step [200/700], Loss: 0.662
# Epoch [23/25], Step [400/700], Loss: 0.668
# Epoch [23/25], Step [600/700], Loss: 0.688
# Epoch [24/25], Step [200/700], Loss: 0.600
# Epoch [24/25], Step [400/700], Loss: 0.660
# Epoch [24/25], Step [600/700], Loss: 0.590
# Epoch [25/25], Step [200/700], Loss: 0.702
# Epoch [25/25], Step [400/700], Loss: 0.629
# Epoch [25/25], Step [600/700], Loss: 0.607

# %%
print("%s seconds" % round((time.time() - start_time),2))

result_df.iloc[0, 5] = round((time.time() - start_time),2)
# Out:
# 52.49 seconds

# %%
classes = ('0', '1')

# %%
model.eval()

# Evaluate the trained model performance

with torch.no_grad():
    
    batch_size = 5
    
    num_correct_preds = 0
    
    num_total = len(test_df)
    
    num_correct_per_label = [0] * len(classes)
    
    num_total_per_label = [0] * len(classes)
    
    num_preds_per_label = [0] * len(classes)
    
    for i, (seqs, labels) in enumerate(test_dataloader):
        
        #seqs = torch.unsqueeze(seqs, 1)
        
        seqs = seqs.to(device)
        
        labels = labels.to(device)
        
        outputs = model(seqs)
        
        # Return the value with the highest probability score
        
        _, pred_values = torch.max(outputs, 1)
        
        num_correct_preds += (pred_values == labels).sum().item()        
    
        for i in range(batch_size):
            
            label = labels[i]
            
            pred_val = pred_values[i]
            
            #print(pred_values)
            
            num_total_per_label[label] += 1
            
            num_preds_per_label[pred_val] += 1
            
            if label == pred_val:
                
                num_correct_per_label[label] += 1
                
    # Calculate Overall Accuracy
    
    overall_accuracy = 100.0 * num_correct_preds / num_total
    
    print(f'Overall accuracy of the model: {overall_accuracy:.3f} %')
    
    result_df.iloc[0, 0] = round(overall_accuracy, 3)
    
    # Calculate Accuracy per Label
    
    for i in range(len(classes)):
        
        accuracy_per_label = 100.0 * num_correct_per_label[i] / num_total_per_label[i]
        
        precision_per_label = 100.0 * num_correct_per_label[i] / num_preds_per_label[i]
        
        print(f'Accuracy of Label {classes[i]} : {accuracy_per_label:.3f} %')
        
        result_df.iloc[0, i+1] = round(accuracy_per_label, 3) 
        
        print(f'Precision of Label {classes[i]} : {precision_per_label:.3f} %')
        
        result_df.iloc[0, i+3] = round(precision_per_label, 3)
# Out:
# Overall accuracy of the model: 58.880 %
# Accuracy of Label 0 : 99.727 %
# Precision of Label 0 : 58.760 %
# Accuracy of Label 1 : 1.254 %
# Precision of Label 1 : 76.471 %

# %% [markdown]
# ## Hidden Layer Size = 8

# %%
model = NeuralNetwork(hidden_size_1 = 8, hidden_size_2 = 8)

# %%
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr = 1e-5, amsgrad = True)

epochs = 25

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
model = model.to(device)

# %%
start_time = time.time()

# %%
loss_count = 0

model.train()

for epoch in range(epochs):
    
    for i, (seqs, labels) in enumerate(train_dataloader):
        
        #labels = torch.unsqueeze(labels, 1)
        
        #seqs = torch.unsqueeze(seqs, 1)
        
        seqs = seqs.to(device)
        
        labels = labels.to(device)
        
        outputs = model(seqs)
        
        loss = criterion(outputs, labels)
        
        optimizer.zero_grad()
        
        loss.backward()
        
        optimizer.step()
        
        if (i+1) % 200 == 0:
            
            print (f'Epoch [{epoch+1}/{epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.3f}')
            
            epoch_df.iloc[loss_count, 2] = round(loss.item(), 2)
            
            loss_count += 1
# Out:
# Epoch [1/25], Step [200/700], Loss: 0.696
# Epoch [1/25], Step [400/700], Loss: 0.691
# Epoch [1/25], Step [600/700], Loss: 0.688
# Epoch [2/25], Step [200/700], Loss: 0.679
# Epoch [2/25], Step [400/700], Loss: 0.674
# Epoch [2/25], Step [600/700], Loss: 0.672
# Epoch [3/25], Step [200/700], Loss: 0.741
# Epoch [3/25], Step [400/700], Loss: 0.672
# Epoch [3/25], Step [600/700], Loss: 0.701
# Epoch [4/25], Step [200/700], Loss: 0.701
# Epoch [4/25], Step [400/700], Loss: 0.670
# Epoch [4/25], Step [600/700], Loss: 0.678
# Epoch [5/25], Step [200/700], Loss: 0.637
# Epoch [5/25], Step [400/700], Loss: 0.724
# Epoch [5/25], Step [600/700], Loss: 0.642
# Epoch [6/25], Step [200/700], Loss: 0.597
# Epoch [6/25], Step [400/700], Loss: 0.686
# Epoch [6/25], Step [600/700], Loss: 0.656
# Epoch [7/25], Step [200/700], Loss: 0.625
# Epoch [7/25], Step [400/700], Loss: 0.700
# Epoch [7/25], Step [600/700], Loss: 0.580
# Epoch [8/25], Step [200/700], Loss: 0.650
# Epoch [8/25], Step [400/700], Loss: 0.741
# Epoch [8/25], Step [600/700], Loss: 0.635
# Epoch [9/25], Step [200/700], Loss: 0.690
# Epoch [9/25], Step [400/700], Loss: 0.690
# Epoch [9/25], Step [600/700], Loss: 0.570
# Epoch [10/25], Step [200/700], Loss: 0.651
# Epoch [10/25], Step [400/700], Loss: 0.633
# Epoch [10/25], Step [600/700], Loss: 0.656
# Epoch [11/25], Step [200/700], Loss: 0.601
# Epoch [11/25], Step [400/700], Loss: 0.709
# Epoch [11/25], Step [600/700], Loss: 0.628
# Epoch [12/25], Step [200/700], Loss: 0.653
# Epoch [12/25], Step [400/700], Loss: 0.668
# Epoch [12/25], Step [600/700], Loss: 0.656
# Epoch [13/25], Step [200/700], Loss: 0.680
# Epoch [13/25], Step [400/700], Loss: 0.582
# Epoch [13/25], Step [600/700], Loss: 0.599
# Epoch [14/25], Step [200/700], Loss: 0.688
# Epoch [14/25], Step [400/700], Loss: 0.618
# Epoch [14/25], Step [600/700], Loss: 0.662
# Epoch [15/25], Step [200/700], Loss: 0.571
# Epoch [15/25], Step [400/700], Loss: 0.623
# Epoch [15/25], Step [600/700], Loss: 0.607
# Epoch [16/25], Step [200/700], Loss: 0.649
# Epoch [16/25], Step [400/700], Loss: 0.557
# Epoch [16/25], Step [600/700], Loss: 0.641
# Epoch [17/25], Step [200/700], Loss: 0.629
# Epoch [17/25], Step [400/700], Loss: 0.676
# Epoch [17/25], Step [600/700], Loss: 0.593
# Epoch [18/25], Step [200/700], Loss: 0.591
# Epoch [18/25], Step [400/700], Loss: 0.599
# Epoch [18/25], Step [600/700], Loss: 0.575
# Epoch [19/25], Step [200/700], Loss: 0.616
# Epoch [19/25], Step [400/700], Loss: 0.595
# Epoch [19/25], Step [600/700], Loss: 0.599
# Epoch [20/25], Step [200/700], Loss: 0.575
# Epoch [20/25], Step [400/700], Loss: 0.581
# Epoch [20/25], Step [600/700], Loss: 0.678
# Epoch [21/25], Step [200/700], Loss: 0.616
# Epoch [21/25], Step [400/700], Loss: 0.606
# Epoch [21/25], Step [600/700], Loss: 0.553
# Epoch [22/25], Step [200/700], Loss: 0.561
# Epoch [22/25], Step [400/700], Loss: 0.624
# Epoch [22/25], Step [600/700], Loss: 0.530
# Epoch [23/25], Step [200/700], Loss: 0.582
# Epoch [23/25], Step [400/700], Loss: 0.659
# Epoch [23/25], Step [600/700], Loss: 0.617
# Epoch [24/25], Step [200/700], Loss: 0.566
# Epoch [24/25], Step [400/700], Loss: 0.561
# Epoch [24/25], Step [600/700], Loss: 0.557
# Epoch [25/25], Step [200/700], Loss: 0.568
# Epoch [25/25], Step [400/700], Loss: 0.540
# Epoch [25/25], Step [600/700], Loss: 0.618

# %%
print("%s seconds" % round((time.time() - start_time),2))

result_df.iloc[1, 5] = round((time.time() - start_time),2)
# Out:
# 49.5 seconds

# %%
model.eval()

# Evaluate the trained model performance

with torch.no_grad():
    
    batch_size = 5
    
    num_correct_preds = 0
    
    num_total = len(test_df)
    
    num_correct_per_label = [0] * len(classes)
    
    num_total_per_label = [0] * len(classes)
    
    num_preds_per_label = [0] * len(classes)
    
    for i, (seqs, labels) in enumerate(test_dataloader):
        
        #seqs = torch.unsqueeze(seqs, 1)
        
        seqs = seqs.to(device)
        
        labels = labels.to(device)
        
        outputs = model(seqs)
        
        # Return the value with the highest probability score
        
        _, pred_values = torch.max(outputs, 1)
        
        num_correct_preds += (pred_values == labels).sum().item()        
    
        for i in range(batch_size):
            
            label = labels[i]
            
            pred_val = pred_values[i]
            
            #print(pred_values)
            
            num_total_per_label[label] += 1
            
            num_preds_per_label[pred_val] += 1
            
            if label == pred_val:
                
                num_correct_per_label[label] += 1
                
    # Calculate Overall Accuracy
    
    overall_accuracy = 100.0 * num_correct_preds / num_total
    
    print(f'Overall accuracy of the model: {overall_accuracy:.3f} %')
    
    result_df.iloc[1, 0] = round(overall_accuracy, 3)
    
    # Calculate Accuracy per Label
    
    for i in range(len(classes)):
        
        accuracy_per_label = 100.0 * num_correct_per_label[i] / num_total_per_label[i]
        
        precision_per_label = 100.0 * num_correct_per_label[i] / num_preds_per_label[i]
        
        print(f'Accuracy of Label {classes[i]} : {accuracy_per_label:.3f} %')
        
        result_df.iloc[1, i+1] = round(accuracy_per_label, 3) 
        
        print(f'Precision of Label {classes[i]} : {precision_per_label:.3f} %')
        
        result_df.iloc[1, i+3] = round(precision_per_label, 3)
# Out:
# Overall accuracy of the model: 64.120 %
# Accuracy of Label 0 : 88.722 %
# Precision of Label 0 : 63.941 %
# Accuracy of Label 1 : 29.412 %
# Precision of Label 1 : 64.894 %

# %% [markdown]
# ## Hidden Layer Size = 16

# %%
model = NeuralNetwork(hidden_size_1 = 16, hidden_size_2 = 16)

# %%
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr = 1e-5, amsgrad = True)

epochs = 25

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
model = model.to(device)

# %%
start_time = time.time()

# %%
loss_count = 0

model.train()

for epoch in range(epochs):
    
    for i, (seqs, labels) in enumerate(train_dataloader):
        
        #labels = torch.unsqueeze(labels, 1)
        
        #seqs = torch.unsqueeze(seqs, 1)
        
        seqs = seqs.to(device)
        
        labels = labels.to(device)
        
        outputs = model(seqs)
        
        loss = criterion(outputs, labels)
        
        optimizer.zero_grad()
        
        loss.backward()
        
        optimizer.step()
        
        if (i+1) % 200 == 0:
            
            print (f'Epoch [{epoch+1}/{epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.3f}')
            
            epoch_df.iloc[loss_count, 3] = round(loss.item(), 2)
            
            loss_count += 1
# Out:
# Epoch [1/25], Step [200/700], Loss: 0.662
# Epoch [1/25], Step [400/700], Loss: 0.652
# Epoch [1/25], Step [600/700], Loss: 0.679
# Epoch [2/25], Step [200/700], Loss: 0.676
# Epoch [2/25], Step [400/700], Loss: 0.671
# Epoch [2/25], Step [600/700], Loss: 0.610
# Epoch [3/25], Step [200/700], Loss: 0.729
# Epoch [3/25], Step [400/700], Loss: 0.729
# Epoch [3/25], Step [600/700], Loss: 0.641
# Epoch [4/25], Step [200/700], Loss: 0.702
# Epoch [4/25], Step [400/700], Loss: 0.735
# Epoch [4/25], Step [600/700], Loss: 0.718
# Epoch [5/25], Step [200/700], Loss: 0.635
# Epoch [5/25], Step [400/700], Loss: 0.662
# Epoch [5/25], Step [600/700], Loss: 0.688
# Epoch [6/25], Step [200/700], Loss: 0.638
# Epoch [6/25], Step [400/700], Loss: 0.665
# Epoch [6/25], Step [600/700], Loss: 0.643
# Epoch [7/25], Step [200/700], Loss: 0.631
# Epoch [7/25], Step [400/700], Loss: 0.755
# Epoch [7/25], Step [600/700], Loss: 0.651
# Epoch [8/25], Step [200/700], Loss: 0.653
# Epoch [8/25], Step [400/700], Loss: 0.624
# Epoch [8/25], Step [600/700], Loss: 0.631
# Epoch [9/25], Step [200/700], Loss: 0.648
# Epoch [9/25], Step [400/700], Loss: 0.646
# Epoch [9/25], Step [600/700], Loss: 0.628
# Epoch [10/25], Step [200/700], Loss: 0.724
# Epoch [10/25], Step [400/700], Loss: 0.593
# Epoch [10/25], Step [600/700], Loss: 0.648
# Epoch [11/25], Step [200/700], Loss: 0.629
# Epoch [11/25], Step [400/700], Loss: 0.636
# Epoch [11/25], Step [600/700], Loss: 0.651
# Epoch [12/25], Step [200/700], Loss: 0.650
# Epoch [12/25], Step [400/700], Loss: 0.676
# Epoch [12/25], Step [600/700], Loss: 0.609
# Epoch [13/25], Step [200/700], Loss: 0.650
# Epoch [13/25], Step [400/700], Loss: 0.575
# Epoch [13/25], Step [600/700], Loss: 0.632
# Epoch [14/25], Step [200/700], Loss: 0.624
# Epoch [14/25], Step [400/700], Loss: 0.648
# Epoch [14/25], Step [600/700], Loss: 0.679
# Epoch [15/25], Step [200/700], Loss: 0.667
# Epoch [15/25], Step [400/700], Loss: 0.583
# Epoch [15/25], Step [600/700], Loss: 0.616
# Epoch [16/25], Step [200/700], Loss: 0.619
# Epoch [16/25], Step [400/700], Loss: 0.582
# Epoch [16/25], Step [600/700], Loss: 0.606
# Epoch [17/25], Step [200/700], Loss: 0.613
# Epoch [17/25], Step [400/700], Loss: 0.546
# Epoch [17/25], Step [600/700], Loss: 0.646
# Epoch [18/25], Step [200/700], Loss: 0.599
# Epoch [18/25], Step [400/700], Loss: 0.636
# Epoch [18/25], Step [600/700], Loss: 0.629
# Epoch [19/25], Step [200/700], Loss: 0.593
# Epoch [19/25], Step [400/700], Loss: 0.562
# Epoch [19/25], Step [600/700], Loss: 0.615
# Epoch [20/25], Step [200/700], Loss: 0.655
# Epoch [20/25], Step [400/700], Loss: 0.600
# Epoch [20/25], Step [600/700], Loss: 0.593
# Epoch [21/25], Step [200/700], Loss: 0.499
# Epoch [21/25], Step [400/700], Loss: 0.586
# Epoch [21/25], Step [600/700], Loss: 0.566
# Epoch [22/25], Step [200/700], Loss: 0.621
# Epoch [22/25], Step [400/700], Loss: 0.513
# Epoch [22/25], Step [600/700], Loss: 0.527
# Epoch [23/25], Step [200/700], Loss: 0.596
# Epoch [23/25], Step [400/700], Loss: 0.578
# Epoch [23/25], Step [600/700], Loss: 0.580
# Epoch [24/25], Step [200/700], Loss: 0.524
# Epoch [24/25], Step [400/700], Loss: 0.517
# Epoch [24/25], Step [600/700], Loss: 0.560
# Epoch [25/25], Step [200/700], Loss: 0.594
# Epoch [25/25], Step [400/700], Loss: 0.613
# Epoch [25/25], Step [600/700], Loss: 0.559

# %%
print("%s seconds" % round((time.time() - start_time), 2))

result_df.iloc[2, 5] = round((time.time() - start_time), 2)
# Out:
# 49.82 seconds

# %%
model.eval()

# Evaluate the trained model performance

with torch.no_grad():
    
    batch_size = 5
    
    num_correct_preds = 0
    
    num_total = len(test_df)
    
    num_correct_per_label = [0] * len(classes)
    
    num_total_per_label = [0] * len(classes)
    
    num_preds_per_label = [0] * len(classes)
    
    for i, (seqs, labels) in enumerate(test_dataloader):
        
        #seqs = torch.unsqueeze(seqs, 1)
        
        seqs = seqs.to(device)
        
        labels = labels.to(device)
        
        outputs = model(seqs)
        
        # Return the value with the highest probability score
        
        _, pred_values = torch.max(outputs, 1)
        
        num_correct_preds += (pred_values == labels).sum().item()        
    
        for i in range(batch_size):
            
            label = labels[i]
            
            pred_val = pred_values[i]
            
            #print(pred_values)
            
            num_total_per_label[label] += 1
            
            num_preds_per_label[pred_val] += 1
            
            if label == pred_val:
                
                num_correct_per_label[label] += 1
                
    # Calculate Overall Accuracy
    
    overall_accuracy = 100.0 * num_correct_preds / num_total
    
    print(f'Overall accuracy of the model: {overall_accuracy:.3f} %')
    
    result_df.iloc[2, 0] = round(overall_accuracy, 3)
    
    # Calculate Accuracy per Label
    
    for i in range(len(classes)):
        
        accuracy_per_label = 100.0 * num_correct_per_label[i] / num_total_per_label[i]
        
        precision_per_label = 100.0 * num_correct_per_label[i] / num_preds_per_label[i]
        
        print(f'Accuracy of Label {classes[i]} : {accuracy_per_label:.3f} %')
        
        result_df.iloc[2, i+1] = round(accuracy_per_label, 3) 
        
        print(f'Precision of Label {classes[i]} : {precision_per_label:.3f} %')
        
        result_df.iloc[2, i+3] = round(precision_per_label, 3)
# Out:
# Overall accuracy of the model: 64.600 %
# Accuracy of Label 0 : 84.074 %
# Precision of Label 0 : 65.356 %
# Accuracy of Label 1 : 37.126 %
# Precision of Label 1 : 62.298 %

# %% [markdown]
# ## Hidden Layer Size = 32

# %%
model = NeuralNetwork(hidden_size_1 = 32, hidden_size_2 = 32)

# %%
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr = 1e-5, amsgrad = True)

epochs = 25

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
model = model.to(device)

# %%
start_time = time.time()

# %%
loss_count = 0

model.train()

for epoch in range(epochs):
    
    for i, (seqs, labels) in enumerate(train_dataloader):
        
        #labels = torch.unsqueeze(labels, 1)
        
        #seqs = torch.unsqueeze(seqs, 1)
        
        seqs = seqs.to(device)
        
        labels = labels.to(device)
        
        outputs = model(seqs)
        
        loss = criterion(outputs, labels)
        
        optimizer.zero_grad()
        
        loss.backward()
        
        optimizer.step()
        
        if (i+1) % 200 == 0:
            
            print (f'Epoch [{epoch+1}/{epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.3f}')
            
            epoch_df.iloc[loss_count, 4] = round(loss.item(), 2)
            
            loss_count += 1
# Out:
# Epoch [1/25], Step [200/700], Loss: 0.692
# Epoch [1/25], Step [400/700], Loss: 0.666
# Epoch [1/25], Step [600/700], Loss: 0.646
# Epoch [2/25], Step [200/700], Loss: 0.670
# Epoch [2/25], Step [400/700], Loss: 0.648
# Epoch [2/25], Step [600/700], Loss: 0.671
# Epoch [3/25], Step [200/700], Loss: 0.700
# Epoch [3/25], Step [400/700], Loss: 0.667
# Epoch [3/25], Step [600/700], Loss: 0.696
# Epoch [4/25], Step [200/700], Loss: 0.720
# Epoch [4/25], Step [400/700], Loss: 0.626
# Epoch [4/25], Step [600/700], Loss: 0.671
# Epoch [5/25], Step [200/700], Loss: 0.654
# Epoch [5/25], Step [400/700], Loss: 0.676
# Epoch [5/25], Step [600/700], Loss: 0.637
# Epoch [6/25], Step [200/700], Loss: 0.704
# Epoch [6/25], Step [400/700], Loss: 0.642
# Epoch [6/25], Step [600/700], Loss: 0.649
# Epoch [7/25], Step [200/700], Loss: 0.619
# Epoch [7/25], Step [400/700], Loss: 0.609
# Epoch [7/25], Step [600/700], Loss: 0.588
# Epoch [8/25], Step [200/700], Loss: 0.599
# Epoch [8/25], Step [400/700], Loss: 0.643
# Epoch [8/25], Step [600/700], Loss: 0.620
# Epoch [9/25], Step [200/700], Loss: 0.615
# Epoch [9/25], Step [400/700], Loss: 0.630
# Epoch [9/25], Step [600/700], Loss: 0.620
# Epoch [10/25], Step [200/700], Loss: 0.597
# Epoch [10/25], Step [400/700], Loss: 0.587
# Epoch [10/25], Step [600/700], Loss: 0.650
# Epoch [11/25], Step [200/700], Loss: 0.712
# Epoch [11/25], Step [400/700], Loss: 0.645
# Epoch [11/25], Step [600/700], Loss: 0.540
# Epoch [12/25], Step [200/700], Loss: 0.516
# Epoch [12/25], Step [400/700], Loss: 0.613
# Epoch [12/25], Step [600/700], Loss: 0.614
# Epoch [13/25], Step [200/700], Loss: 0.485
# Epoch [13/25], Step [400/700], Loss: 0.609
# Epoch [13/25], Step [600/700], Loss: 0.524
# Epoch [14/25], Step [200/700], Loss: 0.554
# Epoch [14/25], Step [400/700], Loss: 0.534
# Epoch [14/25], Step [600/700], Loss: 0.569
# Epoch [15/25], Step [200/700], Loss: 0.539
# Epoch [15/25], Step [400/700], Loss: 0.524
# Epoch [15/25], Step [600/700], Loss: 0.558
# Epoch [16/25], Step [200/700], Loss: 0.486
# Epoch [16/25], Step [400/700], Loss: 0.469
# Epoch [16/25], Step [600/700], Loss: 0.544
# Epoch [17/25], Step [200/700], Loss: 0.554
# Epoch [17/25], Step [400/700], Loss: 0.533
# Epoch [17/25], Step [600/700], Loss: 0.507
# Epoch [18/25], Step [200/700], Loss: 0.499
# Epoch [18/25], Step [400/700], Loss: 0.559
# Epoch [18/25], Step [600/700], Loss: 0.482
# Epoch [19/25], Step [200/700], Loss: 0.627
# Epoch [19/25], Step [400/700], Loss: 0.483
# Epoch [19/25], Step [600/700], Loss: 0.497
# Epoch [20/25], Step [200/700], Loss: 0.561
# Epoch [20/25], Step [400/700], Loss: 0.508
# Epoch [20/25], Step [600/700], Loss: 0.505
# Epoch [21/25], Step [200/700], Loss: 0.474
# Epoch [21/25], Step [400/700], Loss: 0.486
# Epoch [21/25], Step [600/700], Loss: 0.545
# Epoch [22/25], Step [200/700], Loss: 0.424
# Epoch [22/25], Step [400/700], Loss: 0.616
# Epoch [22/25], Step [600/700], Loss: 0.426
# Epoch [23/25], Step [200/700], Loss: 0.551
# Epoch [23/25], Step [400/700], Loss: 0.487
# Epoch [23/25], Step [600/700], Loss: 0.426
# Epoch [24/25], Step [200/700], Loss: 0.455
# Epoch [24/25], Step [400/700], Loss: 0.455
# Epoch [24/25], Step [600/700], Loss: 0.462
# Epoch [25/25], Step [200/700], Loss: 0.455
# Epoch [25/25], Step [400/700], Loss: 0.476
# Epoch [25/25], Step [600/700], Loss: 0.522

# %%
print("%s seconds" % round((time.time() - start_time), 2))

result_df.iloc[3, 5] = round((time.time() - start_time), 2)
# Out:
# 58.4 seconds

# %%
model.eval()

# Evaluate the trained model performance

with torch.no_grad():
    
    batch_size = 5
    
    num_correct_preds = 0
    
    num_total = len(test_df)
    
    num_correct_per_label = [0] * len(classes)
    
    num_total_per_label = [0] * len(classes)
    
    num_preds_per_label = [0] * len(classes)
    
    for i, (seqs, labels) in enumerate(test_dataloader):
        
        #seqs = torch.unsqueeze(seqs, 1)
        
        seqs = seqs.to(device)
        
        labels = labels.to(device)
        
        outputs = model(seqs)
        
        # Return the value with the highest probability score
        
        _, pred_values = torch.max(outputs, 1)
        
        num_correct_preds += (pred_values == labels).sum().item()        
    
        for i in range(batch_size):
            
            label = labels[i]
            
            pred_val = pred_values[i]
            
            #print(pred_values)
            
            num_total_per_label[label] += 1
            
            num_preds_per_label[pred_val] += 1
            
            if label == pred_val:
                
                num_correct_per_label[label] += 1
                
    # Calculate Overall Accuracy
    
    overall_accuracy = 100.0 * num_correct_preds / num_total
    
    print(f'Overall accuracy of the model: {overall_accuracy:.3f} %')
    
    result_df.iloc[3, 0] = round(overall_accuracy, 3)
    
    # Calculate Accuracy per Label
    
    for i in range(len(classes)):
        
        accuracy_per_label = 100.0 * num_correct_per_label[i] / num_total_per_label[i]
        
        precision_per_label = 100.0 * num_correct_per_label[i] / num_preds_per_label[i]
        
        print(f'Accuracy of Label {classes[i]} : {accuracy_per_label:.3f} %')
        
        result_df.iloc[3, i+1] = round(accuracy_per_label, 3) 
        
        print(f'Precision of Label {classes[i]} : {precision_per_label:.3f} %')
        
        result_df.iloc[3, i+3] = round(precision_per_label, 3)
# Out:
# Overall accuracy of the model: 66.840 %
# Accuracy of Label 0 : 74.163 %
# Precision of Label 0 : 70.638 %
# Accuracy of Label 1 : 56.509 %
# Precision of Label 1 : 60.788 %

# %% [markdown]
# ## Hidden Layer Size = 64

# %%
model = NeuralNetwork(hidden_size_1 = 64, hidden_size_2 = 64)

# %%
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr = 1e-5, amsgrad = True)

epochs = 25

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
model = model.to(device)

# %%
start_time = time.time()

# %%
loss_count = 0

model.train()

for epoch in range(epochs):
    
    for i, (seqs, labels) in enumerate(train_dataloader):
        
        #labels = torch.unsqueeze(labels, 1)
        
        #seqs = torch.unsqueeze(seqs, 1)
        
        seqs = seqs.to(device)
        
        labels = labels.to(device)
        
        outputs = model(seqs)
        
        loss = criterion(outputs, labels)
        
        optimizer.zero_grad()
        
        loss.backward()
        
        optimizer.step()
        
        if (i+1) % 200 == 0:
            
            print (f'Epoch [{epoch+1}/{epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.3f}')
            
            epoch_df.iloc[loss_count, 5] = round(loss.item(), 2)
            
            loss_count += 1
# Out:
# Epoch [1/25], Step [200/700], Loss: 0.678
# Epoch [1/25], Step [400/700], Loss: 0.674
# Epoch [1/25], Step [600/700], Loss: 0.748
# Epoch [2/25], Step [200/700], Loss: 0.672
# Epoch [2/25], Step [400/700], Loss: 0.762
# Epoch [2/25], Step [600/700], Loss: 0.680
# Epoch [3/25], Step [200/700], Loss: 0.693
# Epoch [3/25], Step [400/700], Loss: 0.623
# Epoch [3/25], Step [600/700], Loss: 0.638
# Epoch [4/25], Step [200/700], Loss: 0.587
# Epoch [4/25], Step [400/700], Loss: 0.659
# Epoch [4/25], Step [600/700], Loss: 0.624
# Epoch [5/25], Step [200/700], Loss: 0.707
# Epoch [5/25], Step [400/700], Loss: 0.633
# Epoch [5/25], Step [600/700], Loss: 0.621
# Epoch [6/25], Step [200/700], Loss: 0.575
# Epoch [6/25], Step [400/700], Loss: 0.657
# Epoch [6/25], Step [600/700], Loss: 0.620
# Epoch [7/25], Step [200/700], Loss: 0.626
# Epoch [7/25], Step [400/700], Loss: 0.561
# Epoch [7/25], Step [600/700], Loss: 0.616
# Epoch [8/25], Step [200/700], Loss: 0.591
# Epoch [8/25], Step [400/700], Loss: 0.576
# Epoch [8/25], Step [600/700], Loss: 0.537
# Epoch [9/25], Step [200/700], Loss: 0.559
# Epoch [9/25], Step [400/700], Loss: 0.520
# Epoch [9/25], Step [600/700], Loss: 0.520
# Epoch [10/25], Step [200/700], Loss: 0.560
# Epoch [10/25], Step [400/700], Loss: 0.530
# Epoch [10/25], Step [600/700], Loss: 0.556
# Epoch [11/25], Step [200/700], Loss: 0.503
# Epoch [11/25], Step [400/700], Loss: 0.547
# Epoch [11/25], Step [600/700], Loss: 0.514
# Epoch [12/25], Step [200/700], Loss: 0.473
# Epoch [12/25], Step [400/700], Loss: 0.594
# Epoch [12/25], Step [600/700], Loss: 0.510
# Epoch [13/25], Step [200/700], Loss: 0.522
# Epoch [13/25], Step [400/700], Loss: 0.512
# Epoch [13/25], Step [600/700], Loss: 0.530
# Epoch [14/25], Step [200/700], Loss: 0.487
# Epoch [14/25], Step [400/700], Loss: 0.568
# Epoch [14/25], Step [600/700], Loss: 0.613
# Epoch [15/25], Step [200/700], Loss: 0.470
# Epoch [15/25], Step [400/700], Loss: 0.641
# Epoch [15/25], Step [600/700], Loss: 0.515
# Epoch [16/25], Step [200/700], Loss: 0.440
# Epoch [16/25], Step [400/700], Loss: 0.503
# Epoch [16/25], Step [600/700], Loss: 0.509
# Epoch [17/25], Step [200/700], Loss: 0.438
# Epoch [17/25], Step [400/700], Loss: 0.506
# Epoch [17/25], Step [600/700], Loss: 0.539
# Epoch [18/25], Step [200/700], Loss: 0.422
# Epoch [18/25], Step [400/700], Loss: 0.465
# Epoch [18/25], Step [600/700], Loss: 0.473
# Epoch [19/25], Step [200/700], Loss: 0.486
# Epoch [19/25], Step [400/700], Loss: 0.496
# Epoch [19/25], Step [600/700], Loss: 0.483
# Epoch [20/25], Step [200/700], Loss: 0.401
# Epoch [20/25], Step [400/700], Loss: 0.388
# Epoch [20/25], Step [600/700], Loss: 0.475
# Epoch [21/25], Step [200/700], Loss: 0.411
# Epoch [21/25], Step [400/700], Loss: 0.424
# Epoch [21/25], Step [600/700], Loss: 0.577
# Epoch [22/25], Step [200/700], Loss: 0.453
# Epoch [22/25], Step [400/700], Loss: 0.479
# Epoch [22/25], Step [600/700], Loss: 0.453
# Epoch [23/25], Step [200/700], Loss: 0.433
# Epoch [23/25], Step [400/700], Loss: 0.446
# Epoch [23/25], Step [600/700], Loss: 0.489
# Epoch [24/25], Step [200/700], Loss: 0.397
# Epoch [24/25], Step [400/700], Loss: 0.464
# Epoch [24/25], Step [600/700], Loss: 0.382
# Epoch [25/25], Step [200/700], Loss: 0.362
# Epoch [25/25], Step [400/700], Loss: 0.446
# Epoch [25/25], Step [600/700], Loss: 0.477

# %%
print("%s seconds" % round((time.time() - start_time),2))

result_df.iloc[4, 5] = round((time.time() - start_time), 2)
# Out:
# 57.15 seconds

# %%
model.eval()

# Evaluate the trained model performance

with torch.no_grad():
    
    batch_size = 5
    
    num_correct_preds = 0
    
    num_total = len(test_df)
    
    num_correct_per_label = [0] * len(classes)
    
    num_total_per_label = [0] * len(classes)
    
    num_preds_per_label = [0] * len(classes)
    
    for i, (seqs, labels) in enumerate(test_dataloader):
        
        #seqs = torch.unsqueeze(seqs, 1)
        
        seqs = seqs.to(device)
        
        labels = labels.to(device)
        
        outputs = model(seqs)
        
        # Return the value with the highest probability score
        
        _, pred_values = torch.max(outputs, 1)
        
        num_correct_preds += (pred_values == labels).sum().item()        
    
        for i in range(batch_size):
            
            label = labels[i]
            
            pred_val = pred_values[i]
            
            #print(pred_values)
            
            num_total_per_label[label] += 1
            
            num_preds_per_label[pred_val] += 1
            
            if label == pred_val:
                
                num_correct_per_label[label] += 1
                
    # Calculate Overall Accuracy
    
    overall_accuracy = 100.0 * num_correct_preds / num_total
    
    print(f'Overall accuracy of the model: {overall_accuracy:.3f} %')
    
    result_df.iloc[4, 0] = round(overall_accuracy, 3)
    
    # Calculate Accuracy per Label
    
    for i in range(len(classes)):
        
        accuracy_per_label = 100.0 * num_correct_per_label[i] / num_total_per_label[i]
        
        precision_per_label = 100.0 * num_correct_per_label[i] / num_preds_per_label[i]
        
        print(f'Accuracy of Label {classes[i]} : {accuracy_per_label:.3f} %')
        
        result_df.iloc[4, i+1] = round(accuracy_per_label, 3) 
        
        print(f'Precision of Label {classes[i]} : {precision_per_label:.3f} %')
        
        result_df.iloc[4, i+3] = round(precision_per_label, 3)
# Out:
# Overall accuracy of the model: 66.600 %
# Accuracy of Label 0 : 76.282 %
# Precision of Label 0 : 69.576 %
# Accuracy of Label 1 : 52.941 %
# Precision of Label 1 : 61.272 %

# %% [markdown]
# ## Hidden Layer Size = 128

# %%
model = NeuralNetwork(hidden_size_1 = 128, hidden_size_2 = 128)

# %%
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr = 1e-5, amsgrad = True)

epochs = 25

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
model = model.to(device)

# %%
start_time = time.time()

# %%
loss_count = 0

model.train()

for epoch in range(epochs):
    
    for i, (seqs, labels) in enumerate(train_dataloader):
        
        #labels = torch.unsqueeze(labels, 1)
        
        #seqs = torch.unsqueeze(seqs, 1)
        
        seqs = seqs.to(device)
        
        labels = labels.to(device)
        
        outputs = model(seqs)
        
        loss = criterion(outputs, labels)
        
        optimizer.zero_grad()
        
        loss.backward()
        
        optimizer.step()
        
        if (i+1) % 200 == 0:
            
            print (f'Epoch [{epoch+1}/{epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.3f}')
            
            epoch_df.iloc[loss_count, 6] = round(loss.item(), 2)
            
            loss_count += 1
# Out:
# Epoch [1/25], Step [200/700], Loss: 0.618
# Epoch [1/25], Step [400/700], Loss: 0.677
# Epoch [1/25], Step [600/700], Loss: 0.642
# Epoch [2/25], Step [200/700], Loss: 0.580
# Epoch [2/25], Step [400/700], Loss: 0.667
# Epoch [2/25], Step [600/700], Loss: 0.684
# Epoch [3/25], Step [200/700], Loss: 0.737
# Epoch [3/25], Step [400/700], Loss: 0.617
# Epoch [3/25], Step [600/700], Loss: 0.644
# Epoch [4/25], Step [200/700], Loss: 0.654
# Epoch [4/25], Step [400/700], Loss: 0.613
# Epoch [4/25], Step [600/700], Loss: 0.654
# Epoch [5/25], Step [200/700], Loss: 0.587
# Epoch [5/25], Step [400/700], Loss: 0.597
# Epoch [5/25], Step [600/700], Loss: 0.514
# Epoch [6/25], Step [200/700], Loss: 0.515
# Epoch [6/25], Step [400/700], Loss: 0.525
# Epoch [6/25], Step [600/700], Loss: 0.624
# Epoch [7/25], Step [200/700], Loss: 0.579
# Epoch [7/25], Step [400/700], Loss: 0.547
# Epoch [7/25], Step [600/700], Loss: 0.554
# Epoch [8/25], Step [200/700], Loss: 0.474
# Epoch [8/25], Step [400/700], Loss: 0.477
# Epoch [8/25], Step [600/700], Loss: 0.483
# Epoch [9/25], Step [200/700], Loss: 0.463
# Epoch [9/25], Step [400/700], Loss: 0.517
# Epoch [9/25], Step [600/700], Loss: 0.575
# Epoch [10/25], Step [200/700], Loss: 0.515
# Epoch [10/25], Step [400/700], Loss: 0.586
# Epoch [10/25], Step [600/700], Loss: 0.436
# Epoch [11/25], Step [200/700], Loss: 0.514
# Epoch [11/25], Step [400/700], Loss: 0.403
# Epoch [11/25], Step [600/700], Loss: 0.477
# Epoch [12/25], Step [200/700], Loss: 0.473
# Epoch [12/25], Step [400/700], Loss: 0.516
# Epoch [12/25], Step [600/700], Loss: 0.418
# Epoch [13/25], Step [200/700], Loss: 0.489
# Epoch [13/25], Step [400/700], Loss: 0.434
# Epoch [13/25], Step [600/700], Loss: 0.490
# Epoch [14/25], Step [200/700], Loss: 0.441
# Epoch [14/25], Step [400/700], Loss: 0.502
# Epoch [14/25], Step [600/700], Loss: 0.432
# Epoch [15/25], Step [200/700], Loss: 0.401
# Epoch [15/25], Step [400/700], Loss: 0.459
# Epoch [15/25], Step [600/700], Loss: 0.404
# Epoch [16/25], Step [200/700], Loss: 0.441
# Epoch [16/25], Step [400/700], Loss: 0.487
# Epoch [16/25], Step [600/700], Loss: 0.397
# Epoch [17/25], Step [200/700], Loss: 0.524
# Epoch [17/25], Step [400/700], Loss: 0.390
# Epoch [17/25], Step [600/700], Loss: 0.351
# Epoch [18/25], Step [200/700], Loss: 0.372
# Epoch [18/25], Step [400/700], Loss: 0.423
# Epoch [18/25], Step [600/700], Loss: 0.495
# Epoch [19/25], Step [200/700], Loss: 0.369
# Epoch [19/25], Step [400/700], Loss: 0.532
# Epoch [19/25], Step [600/700], Loss: 0.339
# Epoch [20/25], Step [200/700], Loss: 0.387
# Epoch [20/25], Step [400/700], Loss: 0.410
# Epoch [20/25], Step [600/700], Loss: 0.469
# Epoch [21/25], Step [200/700], Loss: 0.430
# Epoch [21/25], Step [400/700], Loss: 0.356
# Epoch [21/25], Step [600/700], Loss: 0.322
# Epoch [22/25], Step [200/700], Loss: 0.344
# Epoch [22/25], Step [400/700], Loss: 0.360
# Epoch [22/25], Step [600/700], Loss: 0.361
# Epoch [23/25], Step [200/700], Loss: 0.348
# Epoch [23/25], Step [400/700], Loss: 0.437
# Epoch [23/25], Step [600/700], Loss: 0.400
# Epoch [24/25], Step [200/700], Loss: 0.331
# Epoch [24/25], Step [400/700], Loss: 0.370
# Epoch [24/25], Step [600/700], Loss: 0.362
# Epoch [25/25], Step [200/700], Loss: 0.334
# Epoch [25/25], Step [400/700], Loss: 0.349
# Epoch [25/25], Step [600/700], Loss: 0.340

# %%
print("%s seconds" % round((time.time() - start_time), 2))

result_df.iloc[5, 5] = round((time.time() - start_time), 2)
# Out:
# 67.08 seconds

# %%
model.eval()

# Evaluate the trained model performance

with torch.no_grad():
    
    batch_size = 5
    
    num_correct_preds = 0
    
    num_total = len(test_df)
    
    num_correct_per_label = [0] * len(classes)
    
    num_total_per_label = [0] * len(classes)
    
    num_preds_per_label = [0] * len(classes)
    
    for i, (seqs, labels) in enumerate(test_dataloader):
        
        #seqs = torch.unsqueeze(seqs, 1)
        
        seqs = seqs.to(device)
        
        labels = labels.to(device)
        
        outputs = model(seqs)
        
        # Return the value with the highest probability score
        
        _, pred_values = torch.max(outputs, 1)
        
        num_correct_preds += (pred_values == labels).sum().item()        
    
        for i in range(batch_size):
            
            label = labels[i]
            
            pred_val = pred_values[i]
            
            #print(pred_values)
            
            num_total_per_label[label] += 1
            
            num_preds_per_label[pred_val] += 1
            
            if label == pred_val:
                
                num_correct_per_label[label] += 1
                
    # Calculate Overall Accuracy
    
    overall_accuracy = 100.0 * num_correct_preds / num_total
    
    print(f'Overall accuracy of the model: {overall_accuracy:.3f} %')
    
    result_df.iloc[5, 0] = round(overall_accuracy, 3)
    
    # Calculate Accuracy per Label
    
    for i in range(len(classes)):
        
        accuracy_per_label = 100.0 * num_correct_per_label[i] / num_total_per_label[i]
        
        precision_per_label = 100.0 * num_correct_per_label[i] / num_preds_per_label[i]
        
        print(f'Accuracy of Label {classes[i]} : {accuracy_per_label:.3f} %')
        
        result_df.iloc[5, i+1] = round(accuracy_per_label, 3) 
        
        print(f'Precision of Label {classes[i]} : {precision_per_label:.3f} %')
        
        result_df.iloc[5, i+3] = round(precision_per_label, 3)
# Out:
# Overall accuracy of the model: 66.960 %
# Accuracy of Label 0 : 76.487 %
# Precision of Label 0 : 69.894 %
# Accuracy of Label 1 : 53.520 %
# Precision of Label 1 : 61.735 %

# %% [markdown]
# ## Hidden Layer Size = 256

# %%
model = NeuralNetwork(hidden_size_1 = 256, hidden_size_2 = 256)

# %%
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr = 1e-5, amsgrad = True)

epochs = 25

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
model = model.to(device)

# %%
start_time = time.time()

# %%
loss_count = 0

model.train()

for epoch in range(epochs):
    
    for i, (seqs, labels) in enumerate(train_dataloader):
        
        #labels = torch.unsqueeze(labels, 1)
        
        #seqs = torch.unsqueeze(seqs, 1)
        
        seqs = seqs.to(device)
        
        labels = labels.to(device)
        
        outputs = model(seqs)
        
        loss = criterion(outputs, labels)
        
        optimizer.zero_grad()
        
        loss.backward()
        
        optimizer.step()
        
        if (i+1) % 200 == 0:
            
            print (f'Epoch [{epoch+1}/{epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.3f}')
            
            epoch_df.iloc[loss_count, 7] = round(loss.item(), 2)
            
            loss_count += 1
# Out:
# Epoch [1/25], Step [200/700], Loss: 0.639
# Epoch [1/25], Step [400/700], Loss: 0.604
# Epoch [1/25], Step [600/700], Loss: 0.673
# Epoch [2/25], Step [200/700], Loss: 0.741
# Epoch [2/25], Step [400/700], Loss: 0.616
# Epoch [2/25], Step [600/700], Loss: 0.687
# Epoch [3/25], Step [200/700], Loss: 0.664
# Epoch [3/25], Step [400/700], Loss: 0.629
# Epoch [3/25], Step [600/700], Loss: 0.631
# Epoch [4/25], Step [200/700], Loss: 0.652
# Epoch [4/25], Step [400/700], Loss: 0.531
# Epoch [4/25], Step [600/700], Loss: 0.554
# Epoch [5/25], Step [200/700], Loss: 0.557
# Epoch [5/25], Step [400/700], Loss: 0.561
# Epoch [5/25], Step [600/700], Loss: 0.472
# Epoch [6/25], Step [200/700], Loss: 0.439
# Epoch [6/25], Step [400/700], Loss: 0.708
# Epoch [6/25], Step [600/700], Loss: 0.452
# Epoch [7/25], Step [200/700], Loss: 0.507
# Epoch [7/25], Step [400/700], Loss: 0.430
# Epoch [7/25], Step [600/700], Loss: 0.538
# Epoch [8/25], Step [200/700], Loss: 0.528
# Epoch [8/25], Step [400/700], Loss: 0.421
# Epoch [8/25], Step [600/700], Loss: 0.383
# Epoch [9/25], Step [200/700], Loss: 0.632
# Epoch [9/25], Step [400/700], Loss: 0.395
# Epoch [9/25], Step [600/700], Loss: 0.502
# Epoch [10/25], Step [200/700], Loss: 0.438
# Epoch [10/25], Step [400/700], Loss: 0.423
# Epoch [10/25], Step [600/700], Loss: 0.440
# Epoch [11/25], Step [200/700], Loss: 0.502
# Epoch [11/25], Step [400/700], Loss: 0.432
# Epoch [11/25], Step [600/700], Loss: 0.493
# Epoch [12/25], Step [200/700], Loss: 0.397
# Epoch [12/25], Step [400/700], Loss: 0.438
# Epoch [12/25], Step [600/700], Loss: 0.421
# Epoch [13/25], Step [200/700], Loss: 0.349
# Epoch [13/25], Step [400/700], Loss: 0.493
# Epoch [13/25], Step [600/700], Loss: 0.340
# Epoch [14/25], Step [200/700], Loss: 0.451
# Epoch [14/25], Step [400/700], Loss: 0.363
# Epoch [14/25], Step [600/700], Loss: 0.362
# Epoch [15/25], Step [200/700], Loss: 0.357
# Epoch [15/25], Step [400/700], Loss: 0.374
# Epoch [15/25], Step [600/700], Loss: 0.354
# Epoch [16/25], Step [200/700], Loss: 0.466
# Epoch [16/25], Step [400/700], Loss: 0.401
# Epoch [16/25], Step [600/700], Loss: 0.359
# Epoch [17/25], Step [200/700], Loss: 0.341
# Epoch [17/25], Step [400/700], Loss: 0.375
# Epoch [17/25], Step [600/700], Loss: 0.325
# Epoch [18/25], Step [200/700], Loss: 0.449
# Epoch [18/25], Step [400/700], Loss: 0.343
# Epoch [18/25], Step [600/700], Loss: 0.541
# Epoch [19/25], Step [200/700], Loss: 0.323
# Epoch [19/25], Step [400/700], Loss: 0.395
# Epoch [19/25], Step [600/700], Loss: 0.344
# Epoch [20/25], Step [200/700], Loss: 0.347
# Epoch [20/25], Step [400/700], Loss: 0.335
# Epoch [20/25], Step [600/700], Loss: 0.580
# Epoch [21/25], Step [200/700], Loss: 0.341
# Epoch [21/25], Step [400/700], Loss: 0.541
# Epoch [21/25], Step [600/700], Loss: 0.330
# Epoch [22/25], Step [200/700], Loss: 0.354
# Epoch [22/25], Step [400/700], Loss: 0.330
# Epoch [22/25], Step [600/700], Loss: 0.318
# Epoch [23/25], Step [200/700], Loss: 0.342
# Epoch [23/25], Step [400/700], Loss: 0.337
# Epoch [23/25], Step [600/700], Loss: 0.321
# Epoch [24/25], Step [200/700], Loss: 0.339
# Epoch [24/25], Step [400/700], Loss: 0.325
# Epoch [24/25], Step [600/700], Loss: 0.323
# Epoch [25/25], Step [200/700], Loss: 0.435
# Epoch [25/25], Step [400/700], Loss: 0.339
# Epoch [25/25], Step [600/700], Loss: 0.329

# %%
print("%s seconds" % round((time.time() - start_time), 2))

result_df.iloc[6, 5] = round((time.time() - start_time), 2)
# Out:
# 85.31 seconds

# %%
model.eval()

# Evaluate the trained model performance

with torch.no_grad():
    
    batch_size = 5
    
    num_correct_preds = 0
    
    num_total = len(test_df)
    
    num_correct_per_label = [0] * len(classes)
    
    num_total_per_label = [0] * len(classes)
    
    num_preds_per_label = [0] * len(classes)
    
    for i, (seqs, labels) in enumerate(test_dataloader):
        
        #seqs = torch.unsqueeze(seqs, 1)
        
        seqs = seqs.to(device)
        
        labels = labels.to(device)
        
        outputs = model(seqs)
        
        # Return the value with the highest probability score
        
        _, pred_values = torch.max(outputs, 1)
        
        num_correct_preds += (pred_values == labels).sum().item()        
    
        for i in range(batch_size):
            
            label = labels[i]
            
            pred_val = pred_values[i]
            
            #print(pred_values)
            
            num_total_per_label[label] += 1
            
            num_preds_per_label[pred_val] += 1
            
            if label == pred_val:
                
                num_correct_per_label[label] += 1
                
    # Calculate Overall Accuracy
    
    overall_accuracy = 100.0 * num_correct_preds / num_total
    
    print(f'Overall accuracy of the model: {overall_accuracy:.3f} %')
    
    result_df.iloc[6, 0] = round(overall_accuracy, 3)
    
    # Calculate Accuracy per Label
    
    for i in range(len(classes)):
        
        accuracy_per_label = 100.0 * num_correct_per_label[i] / num_total_per_label[i]
        
        precision_per_label = 100.0 * num_correct_per_label[i] / num_preds_per_label[i]
        
        print(f'Accuracy of Label {classes[i]} : {accuracy_per_label:.3f} %')
        
        result_df.iloc[6, i+1] = round(accuracy_per_label, 3) 
        
        print(f'Precision of Label {classes[i]} : {precision_per_label:.3f} %')
        
        result_df.iloc[6, i+3] = round(precision_per_label, 3)
# Out:
# Overall accuracy of the model: 66.800 %
# Accuracy of Label 0 : 71.634 %
# Precision of Label 0 : 71.634 %
# Accuracy of Label 1 : 59.981 %
# Precision of Label 1 : 59.981 %

# %%
epoch_df
# Out:
#     epoch_value  loss_value_4  loss_value_8  loss_value_16  loss_values_32  \
# 0           0.3          0.70          0.70           0.66            0.69
# 1           0.7          0.64          0.69           0.65            0.67
# 2           1.0          0.68          0.69           0.68            0.65
# 3           1.3          0.71          0.68           0.68            0.67
# 4           1.7          0.60          0.67           0.67            0.65
# ..          ...           ...           ...            ...             ...
# 70         23.7          0.66          0.56           0.52            0.45
# 71         24.0          0.59          0.56           0.56            0.46
# 72         24.3          0.70          0.57           0.59            0.45
# 73         24.7          0.63          0.54           0.61            0.48
# 74         25.0          0.61          0.62           0.56            0.52
#
#     loss_value_64  loss_values_128  loss_values_256
# 0            0.68             0.62             0.64
# 1            0.67             0.68             0.60
# 2            0.75             0.64             0.67
# 3            0.67             0.58             0.74
# 4            0.76             0.67             0.62
# ..            ...              ...              ...
# 70           0.46             0.37             0.32
# 71           0.38             0.36             0.32
# 72           0.36             0.33             0.44
# 73           0.45             0.35             0.34
# 74           0.48             0.34             0.33
#
# [75 rows x 8 columns]

# %%
epoch_df.to_csv("loss_values_v5.csv")

# %%
result_df
# Out:
#                  overall_accuracy  accuracy_not_gout  accuracy_gout  \
# hidden_size_4               58.88             99.727          1.254
# hidden_size_8               64.12             88.722         29.412
# hidden_size_16              64.60             84.074         37.126
# hidden_size_32              66.84             74.163         56.509
# hidden_size_64              66.60             76.282         52.941
# hidden_size_128             66.96             76.487         53.520
# hidden_size_256             66.80             71.634         59.981
#
#                  precision_not_gout  precision_gout  training_time
# hidden_size_4                58.760          76.471          52.49
# hidden_size_8                63.941          64.894          49.50
# hidden_size_16               65.356          62.298          49.82
# hidden_size_32               70.638          60.788          58.40
# hidden_size_64               69.576          61.272          57.15
# hidden_size_128              69.894          61.735          67.09
# hidden_size_256              71.634          59.981          85.32

# %%
result_df['f1_score_gout'] = round((2 * (result_df['accuracy_gout'] * result_df['precision_gout']) / 
                              (result_df['accuracy_gout'] + result_df['precision_gout'])), 2)

# %%
result_df
# Out:
#                  overall_accuracy  accuracy_not_gout  accuracy_gout  \
# hidden_size_4               58.88             99.727          1.254
# hidden_size_8               64.12             88.722         29.412
# hidden_size_16              64.60             84.074         37.126
# hidden_size_32              66.84             74.163         56.509
# hidden_size_64              66.60             76.282         52.941
# hidden_size_128             66.96             76.487         53.520
# hidden_size_256             66.80             71.634         59.981
#
#                  precision_not_gout  precision_gout  training_time  \
# hidden_size_4                58.760          76.471          52.49
# hidden_size_8                63.941          64.894          49.50
# hidden_size_16               65.356          62.298          49.82
# hidden_size_32               70.638          60.788          58.40
# hidden_size_64               69.576          61.272          57.15
# hidden_size_128              69.894          61.735          67.09
# hidden_size_256              71.634          59.981          85.32
#
#                  f1_score_gout
# hidden_size_4             2.47
# hidden_size_8            40.48
# hidden_size_16           46.53
# hidden_size_32           58.57
# hidden_size_64           56.80
# hidden_size_128          57.33
# hidden_size_256          59.98

# %%
result_df.to_csv('snn_enc_v5.csv')

# %%
abc = pd.read_csv("snn_enc_v5.csv")

# %%
abc
# Out:
#         Unnamed: 0  overall_accuracy  accuracy_not_gout  accuracy_gout  \
# 0    hidden_size_4             58.88             99.727          1.254
# 1    hidden_size_8             64.12             88.722         29.412
# 2   hidden_size_16             64.60             84.074         37.126
# 3   hidden_size_32             66.84             74.163         56.509
# 4   hidden_size_64             66.60             76.282         52.941
# 5  hidden_size_128             66.96             76.487         53.520
# 6  hidden_size_256             66.80             71.634         59.981
#
#    precision_not_gout  precision_gout  training_time  f1_score_gout
# 0              58.760          76.471          52.49           2.47
# 1              63.941          64.894          49.50          40.48
# 2              65.356          62.298          49.82          46.53
# 3              70.638          60.788          58.40          58.57
# 4              69.576          61.272          57.15          56.80
# 5              69.894          61.735          67.09          57.33
# 6              71.634          59.981          85.32          59.98

# %%
plt.plot(epoch_df['epoch_value'], epoch_df['loss_value_4'], color = "green", label = "Hidden Size 4")

#plt.plot(epoch_df['epoch_value'], epoch_df['loss_value_8'], color = "yellow", label = "hidden size 8")

plt.plot(epoch_df['epoch_value'], epoch_df['loss_value_16'], color = "blue", label = "Hidden Size 16")

#plt.plot(epoch_df['epoch_value'], epoch_df['loss_values_32'], color = "purple", label = "hidden size 32")

plt.plot(epoch_df['epoch_value'], epoch_df['loss_value_64'], color = "red", label = "Hidden Size 64")

#plt.plot(epoch_df['epoch_value'], epoch_df['loss_values_128'], color = "orange", label = "hidden size 128")

plt.plot(epoch_df['epoch_value'], epoch_df['loss_values_256'], color = "black", label = "Hidden Size 256")

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.title('Loss Values at each Epoch of Different Feedforward Neural Network Models')

plt.xlabel('Epoch')

plt.ylabel('Loss Value')

plt.grid(True)

plt.show()
